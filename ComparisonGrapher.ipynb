# %%
import Data_16_8  
import Data_8_4  
import Data_17_32
import Data_40
import Data_60
import Data_80
import Data_New
import Data_Old

import importlib

importlib.reload(Data_16_8)
importlib.reload(Data_8_4)
importlib.reload(Data_17_32)
importlib.reload(Data_40)
importlib.reload(Data_60)
importlib.reload(Data_80)
importlib.reload(Data_New)
importlib.reload(Data_Old)
# Out:
# <module 'Data_Old' from 'd:\\skolo\\ProektnaMatura\\Data_Old.py'>

# %%
from statistics import mode, median,mean
import Ploter as plt
def GetDataSet(Data,func):
    return [func([val for val in gen]) for gen in Data.Data]
TQM = lambda arr: mean(arr[:len(arr)//4])

importlib.reload(plt)

# plt.plot_two([
#     (GetDataSet(DataA,max),[1,11],{1: 'indigo', "plot":"tab:purple" , 11:"m"},{1:'--',11:'-'},"16,8"),
#     (GetDataSet(DataB,max),[1,10],{1: 'darkslategray', "plot":"c" , 10: "teal"},{1:'--',10:'-'},"8,4"),
#     (GetDataSet(DataA,mean),[1,11],{1: 'indigo', "plot":"tab:purple" , 11:"m"},{1:'--',11:'-'},"16,8"),
#     (GetDataSet(DataB,mean),[1,10],{1: 'darkslategray', "plot":"c" , 10: "teal"},{1:'--',10:'-'},"8,4")
#     ],"16,8 vs 8,4","Генерација","Поволност",(6,5))

# plt.plot_two([
#     (GetDataSet(Data_80,max),[1,11],{1: 'indigo', "plot":"tab:purple" , 11:"m"},{1:'--',11:'-'},"80%"),
#     (GetDataSet(Data_40,max),[1,11],{1: 'darkslategray', "plot":"c" , 11: "teal"},{1:'--',11:'-'},"40%"),
#     (GetDataSet(Data_60,max),[1,11],{1: 'maroon', "plot":"tab:red" , 11:"r"},{1:'--',11:'-'},"60%"),
#     ],"бр. Преживувачи Max","Генерација","Поволност",(6,5))

plt.plot_two([
    (GetDataSet(Data_80,TQM),[1,11],{1: 'indigo', "plot":"tab:purple" , 11:"m"},{1:'--',11:'-'},"80%"),
    (GetDataSet(Data_40,TQM),[1,11],{1: 'darkslategray', "plot":"c" , 11: "teal"},{1:'--',11:'-'},"40%"),
    (GetDataSet(Data_60,TQM),[1,11],{1: 'maroon', "plot":"tab:red" , 11:"r"},{1:'--',11:'-'},"60%"),
    ],"Просек на Q1 според бр. на Преживувачи","Генерација","Поволност",(5,4))
plt.plot_two([
    (GetDataSet(Data_New,TQM),[1,11],{1: 'indigo', "plot":"tab:purple" , 11:"m"},{1:'--',11:'-'},"Подредување"),
    (GetDataSet(Data_Old,TQM),[1,11],{1: 'darkslategray', "plot":"c" , 11: "teal"},{1:'--',11:'-'},"Турнир"),
    ],"Просек на Q1 според начин на Рангирање","Генерација","Поволност",(5,4))
plt.plot_two([
    (GetDataSet(Data_16_8,TQM),[1,11],{1: 'indigo', "plot":"tab:purple" , 11:"m"},{1:'--',11:'-'},"16, 8"),
    (GetDataSet(Data_8_4,TQM),[1,11],{1: 'darkslategray', "plot":"c" , 11: "teal"},{1:'--',11:'-'},"8, 4"),
    ],"Просек на Q1 според начин Според бр. на перцептрони","Генерација","Поволност",(5,4))
plt.plot_two([
    (GetDataSet(Data_16_8,TQM),[1,11],{1: 'indigo', "plot":"tab:purple" , 11:"m"},{1:'--',11:'-'},"Поени"),    
    ],"Просек на Q1 на Финалниот експеримент","Генерација","Поволност",(5,4))


# plt.plot_two([
#     (GetDataSet(Data_80,mean),[1,11],{1: 'indigo', "plot":"tab:purple" , 11:"m"},{1:'--',11:'-'},"80%"),
#     (GetDataSet(Data_40,mean),[1,11],{1: 'darkslategray', "plot":"c" , 11: "teal"},{1:'--',11:'-'},"40%"),
#     (GetDataSet(Data_60,mean),[1,11],{1: 'maroon', "plot":"tab:red" , 11:"r"},{1:'--',11:'-'},"60%"),
#     ],"бр. Преживувачи Просек","Генерација","Поволност",(6,5))
# Out:
# c:\Users\bojan\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=2.76579e-72): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\bojan\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=2.76579e-72): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\bojan\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=2.76579e-72): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\bojan\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=2.45591e-76): result may not be accurate.
# ...
